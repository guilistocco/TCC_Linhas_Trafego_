# %%
import pandas as pd
import random

# %%
nulooo = 'NULL'
espacoo = ' '
lista_nula = []


for i in range(300):
    lista_nula.append(nulooo + i*espacoo)
    lista_nula.append(i*espacoo + nulooo)
    # print(nulooo + i*espacoo)
    # print(i*espacoo + nulooo)
# lista_nula

# %% [markdown]
# ## Documentação dos dados de eventos e operações de alteração de trafego

# %%
p = 0.1
planejamento = pd.read_csv(r'D:\Users\guilh\Documents\[[POLI] TCC 1\Dados\Dados Sptrans (CD Hackatona)\ABCadastro\ABCdPjD.txt',
                encoding = 'ANSI',header = 0 ,  sep = '|', delimiter='|',skipinitialspace =True, na_values=lista_nula, skiprows=lambda i: i>0 and random.random() > p)
                
planejamento = planejamento.rename(columns=lambda x: x.strip())
planejamento = planejamento[1:planejamento.shape[0]-1]

planejamento
# Out:
#        CdPjOID  DfLogIDOperacao  DfRevIDFrota  DfRevIDTempo  \
# 1            7                1           1.0           1.0
# 2            7                1           1.0           1.0
# 3           11                1           1.0           1.0
# 4           12                1           1.0           1.0
# 5           12                1           1.0           1.0
# ...        ...              ...           ...           ...
# 19624    77704                1           0.0           0.0
# 19625    77709                1           0.0           0.0
# 19626    77718                1           0.0           0.0
# 19627    77719                1           0.0           0.0
# 19628    77720                1           0.0           0.0
#
#        DfRevIDPartidaIda  DfRevIDPartidaVolta  DfRevIDItiIda  DfRevIDItiVolta  \
# 1                    1.0                  1.0            1.0              1.0
# 2                    1.0                  1.0            1.0              1.0
# ...

# %% [markdown]
# ## Itinerários "geograficos" sao compostos de trechos
#
# alem disso, os itinerários tambem tem os seus dados qualitativos como nome, codigo, placa da linha

# %%
p = 0.1
trechos = pd.read_csv(r'D:\Users\guilh\Documents\[[POLI] TCC 1\Dados\Dados Sptrans (CD Hackatona)\ABCadastro\ABGfCrd.txt',
                encoding = 'ANSI',header = 0 ,  sep = '|', delimiter='|',skipinitialspace =True, na_values=lista_nula)#, skiprows=lambda i: i>0 and random.random() > p)
                
trechos = trechos.rename(columns=lambda x: x.strip())
trechos = trechos[1:trechos.shape[0]-1]

# trechos
# Out:
# d:\Users\guilh\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (0,1,2,3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
p = 0.1
itinerarios_quali = pd.read_csv(r'D:\Users\guilh\Documents\[[POLI] TCC 1\Dados\Dados Sptrans (CD Hackatona)\ABCadastro\ABSvIti.txt',
                encoding = 'ANSI',header = 0 ,  sep = '|', delimiter='|',skipinitialspace =True, na_values=lista_nula)#, skiprows=lambda i: i>0 and random.random() > p)
                
itinerarios_quali = itinerarios_quali.rename(columns=lambda x: x.strip())
itinerarios_quali = itinerarios_quali[1:itinerarios_quali.shape[0]-1]

itinerarios_quali
# Out:
#       SvItiID SvItiExtensao SvItiRefPercurso    CdParID CdParIDVirada  \
# 1         214        25.720              NaN        NaN           NaN
# 2         215         6.010              NaN        NaN           NaN
# 3         216         5.920              NaN        NaN           NaN
# 4         217        10.910              NaN        NaN           NaN
# 5         218        21.510              NaN        NaN           NaN
# ...       ...           ...              ...        ...           ...
# 30270   47813        25.223              NaN  540014253     950006508
# 30271   47814        18.488              NaN  740006493           NaN
# 30272   47817        24.709              NaN  870005576           NaN
# 30273   47835        19.728              NaN        NaN           NaN
# 30274   47836        19.547              NaN  700013999           NaN
#
#       SvItiPlacaFrontal SvItiPlacaLateral SvItiPlacaComplementar DfSItID  \
# ...

# %%
p = 0.1
itinerarios = pd.read_csv(r'D:\Users\guilh\Documents\[[POLI] TCC 1\Dados\Dados Sptrans (CD Hackatona)\ABCadastro\ABSvTIt.txt',
                encoding = 'ANSI',header = 0 ,  sep = '|', delimiter='|',skipinitialspace =True, na_values=lista_nula)#, skiprows=lambda i: i>0 and random.random() > p)
                
itinerarios = itinerarios.rename(columns=lambda x: x.strip())
itinerarios = itinerarios[1:itinerarios.shape[0]-1]

itinerarios.head()
# Out:
# d:\Users\guilh\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (0,1,2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   SvItiID SvTItSequencia GfTreID SvTItDirecao
# 1  -44996              1  209989            1
# 2  -44996              9  209968            1
# 3  -44996             12  209966            1
# 4  -44996             13  204875           -1
# 5  -44996             14   81728           -1

# %%
trechos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522508 entries, 1 to 522508
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   GfTreID         522508 non-null  object
#  1   GfCrdSequencia  522508 non-null  object
#  2   GfCrdLongitude  522508 non-null  object
#  3   GfCrdLatitude   522508 non-null  object
#  4   GfCrdDistancia  522508 non-null  object
# dtypes: object(5)
# memory usage: 19.9+ MB

# %%
itinerarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6708057 entries, 1 to 6708057
# Data columns (total 4 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   SvItiID         object
#  1   SvTItSequencia  object
#  2   GfTreID         object
#  3   SvTItDirecao    object
# dtypes: object(4)
# memory usage: 204.7+ MB

# %% [markdown]
# ### Perguntas
#
# - por quantos trechos eh composto um itinerario, em media?
# - qual itinerario tem mais trechos?
# - qual o trecho mais comum (presente em mais itinerarios) e onde ele fica? paulista, algum corredor de onibus 23, 9 de julho, reboucas ou areas fora do centro mais densamente habitadas
# -

# %% [markdown]
# #### trechos por itinerario
#
# em media, sao 220 trechos por itinerario

# %%
itinerarios['SvItiID'].value_counts().mean()
# Out:
# 220.31914474332447

# %%
itinerarios['SvItiID'].value_counts().plot(kind='hist')

# %%
# pontos_itine = itinerarios.merge(trechos, on='GfTreID', how='left')

# %% [markdown]
# #### itinerario com mais trechos

# %%
pd.DataFrame(itinerarios['SvItiID'].value_counts()[:10].values, columns=['quantidade_trechos'],index = itinerarios['SvItiID'].value_counts()[:10].index)
# Out:
#        quantidade_trechos
# 2773                 1198
# 3649                 1198
# 9062                 1194
# 9064                 1194
# 9066                 1194
# 45425                1180
# 29621                1134
# 44465                1129
# 20905                1124
# 20249                1124

# %% [markdown]
# #### qual o trecho mais comum (presente em mais itinerarios) e onde ele fica?
#
# pouquissimos trechos (menos de 250 dentre 550k) aparecem dezenas de milhares de vezes

# %%
itinerarios['GfTreID'].value_counts()
# Out:
# 118534    1707
# 61590     1698
# 61591     1695
# 31934     1581
# 31932     1579
#           ...
# 75361        1
# 172956       1
# 172933       1
# 46301        1
# 49177        1
# Name: GfTreID, Length: 99381, dtype: int64

# %%
itinerarios['GfTreID'].value_counts().plot(kind='hist')

# %% [markdown]
# os trechos mais frequentes em SP pelas linhas de onibus ficam:
#  - Largo da Batata
#  - Ao lado a estacao BRAS da CPTM
#  - Av Celso Garcia, mas ainda perto da estacao BRAS

# %%
trechos.loc[trechos['GfTreID'].isin(itinerarios['GfTreID'].value_counts()[:10].index)][['GfTreID', 'GfCrdLatitude','GfCrdLongitude']]
# Out:
#        GfTreID GfCrdLatitude GfCrdLongitude
# 182000   61588     -23566658      -46694401
# 182001   61588     -23566509      -46694393
# 182002   61590     -23565902      -46694665
# 182003   61590     -23566098      -46694623
# 182004   61591     -23565480      -46694699
# 182005   61591     -23565902      -46694665
# 333700  118531     -23542925      -46616365
# 333701  118531     -23542638      -46615991
# 333707  118534     -23542638      -46615991
# 333708  118534     -23542451      -46615753

# %% [markdown]
# #### linha com mais trechos tem realmente a maior extensao ?
#
#
# -- ainda nao consegui encontrar como relacionar LINHA com ITINERARIO

# %%
itinerarios_quali[itinerarios_quali['SvItiID'] == 2773]
# Out:
# Empty DataFrame
# Columns: [SvItiID, SvItiExtensao, SvItiRefPercurso, CdParID, CdParIDVirada, SvItiPlacaFrontal, SvItiPlacaLateral, SvItiPlacaComplementar, DfSItID, DfLogIDAtualizar]
# Index: []

# %%
len(itinerarios_quali['SvItiID'].unique())
# Out:
# 30274

# %%
itinerarios['SvItiID'].value_counts()
# Out:
# 2773     1198
# 3649     1198
# 9062     1194
# 9064     1194
# 9066     1194
#          ...
# 10535       1
# 40298       1
# 10529       1
# 6449        1
# 10537       1
# Name: SvItiID, Length: 30447, dtype: int64

# %%
itinerarios_quali.loc[itinerarios_quali['SvItiID'].isin(itinerarios['SvItiID'].value_counts()[:10].index)]
# Out:
# Empty DataFrame
# Columns: [SvItiID, SvItiExtensao, SvItiRefPercurso, CdParID, CdParIDVirada, SvItiPlacaFrontal, SvItiPlacaLateral, SvItiPlacaComplementar, DfSItID, DfLogIDAtualizar]
# Index: []

# %% [markdown]
# ## exemplo de eventos viarios, datas variam de 2003 a 2013

# %%
p = 0.1
eventos_viarios = pd.read_csv(r'D:\Users\guilh\Documents\[[POLI] TCC 1\Dados\Dados Sptrans (CD Hackatona)\ABCadastro\ABCdEve.txt',
                encoding = 'ANSI',header = 0 ,  sep = '|', delimiter='|',skipinitialspace =True, na_values=lista_nula, skiprows=lambda i: i>0 and random.random() > p)
                
eventos_viarios = eventos_viarios.rename(columns=lambda x: x.strip())

# itinerarios_alternativos = itinerarios_alternativos[1:itinerarios_alternativos.shape[0]-1]
eventos_viarios.head()
# Out:
#                                              CdEveID         CdEveDataHoraIni  \
# 0                                                 36  2005-05-22 08:00:00.000
# 1                                       Itinerário:                       NaN
# 2                           ITINERÁRIO ALTERNATIVO:                       NaN
# 3  978T/10 - Ida: Rua Itambé do Mato Dentro, norm...                      NaN
# 4                     233A/10 – “Jd. Helena – Ceret”                      NaN
#
#           CdEveDataHoraFim             CdEveHoraIni             CdEveHoraFim  \
# 0  2005-05-22 13:00:00.000  1900-01-01 08:00:00.000  1900-01-01 13:00:00.000
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
# ...

# %%
p = 0.1
locais = pd.read_csv(r'D:\Users\guilh\Documents\[[POLI] TCC 1\Dados\Dados Sptrans (CD Hackatona)\ABCadastro\ABCdLoc.txt',
                encoding = 'ANSI',header = 0 ,  sep = '|', delimiter='|',skipinitialspace =True, na_values=lista_nula)

# data = data[1:data.shape[0]-1]
locais
# Out:
#                  CdLocID      \
# 0                -----------
# 1                         15
# 2                         16
# 3                         17
# 4                         21
# ...                      ...
# 16561                  16592
# 16562                  16593
# 16563                  16594
# 16564                  16595
# 16565  (16564 rows affected)
#
#       CdLocEndereco                                       CdLocNumero  \
# 0      ----------------------------------------------...  -----------
# 1      TERMINAL PARQUE D. PEDRO II                   ...            0
# 2      TERMINAL SANTO AMARO                          ...            0
# 3      TERMINAL PARELHEIROS                          ...            0
# 4      Rua santa rita                                ...            0
# ...                                                  ...          ...
# 16561  AV. paulista                                  ...            0
# ...

# %%
p = 0.1
totais_viagens = pd.read_csv(r'D:\Users\guilh\Documents\[[POLI] TCC 1\Dados\Dados Sptrans (CD Hackatona)\ABCadastro\ABSvVgH.txt',
                encoding = 'ANSI',header = 0 ,  sep = '|', delimiter='|',skipinitialspace =True, na_values=lista_nula, skiprows=lambda i: i>0 and random.random() > p)

totais_viagens = totais_viagens.rename(columns=lambda x: x.strip())
totais_viagens = totais_viagens[1:totais_viagens.shape[0]-1]
totais_viagens
# Out:
#         SvQdPID  SvVgHNumViag  SvVgHFaixa  DfVgmCodigo
# 1             2             2           0  P
# 2             2             7          14  P
# 3             2             7          16  P
# 4             3             8          14  P
# 5             3             8          16  P
# ...         ...           ...         ...          ...
# 689517   151301             0           0  S
# 689518   151301             1           5  P
# 689519   151301             0           5  R
# 689520   151301             0          11  E
# 689521   151301             0          20  S
#
# [689521 rows x 4 columns]

# %%
p = 0.1
linhas = pd.read_csv(r'D:\Users\guilh\Documents\[[POLI] TCC 1\Dados\Dados Sptrans (CD Hackatona)\ABCadastro\ABTpLin.txt',
                encoding = 'ANSI',header = 0 ,  sep = '|', delimiter='|',skipinitialspace =True, na_values=lista_nula)#, skiprows=lambda i: i>0 and random.random() > p)
                
linhas = linhas.rename(columns=lambda x: x.strip())
linhas = linhas[1:linhas.shape[0]-1]

# linhas

# %%
p = 0.1
linhas2 = pd.read_csv(r'D:\Users\guilh\Documents\[[POLI] TCC 1\Dados\Dados Sptrans (CD Hackatona)\ABCadastro\ABSvLin.txt',
                encoding = 'ANSI',header = 0 ,  sep = '|', delimiter='|',skipinitialspace =True, na_values=lista_nula)#, skiprows=lambda i: i>0 and random.random() > p)
                
linhas2 = linhas2.rename(columns=lambda x: x.strip())
linhas2 = linhas2[1:linhas2.shape[0]-1]

linhas2
# Out:
#       SvLinCodigo TpLinID         SvLinDataCriacao    SvLinDataInicOperacao  \
# 1     1002             10  2001-11-17 00:00:00.000  2003-05-17 00:00:00.000
# 2     1016             10  2002-05-17 00:00:00.000  2003-05-17 00:00:00.000
# 3     1016             51  2010-08-07 00:00:00.000  2010-08-07 00:00:00.000
# 4     1017             10  2012-11-24 00:00:00.000  2012-11-24 00:00:00.000
# 5     1018             10  2001-12-15 00:00:00.000  2003-05-17 00:00:00.000
# ...           ...     ...                      ...                      ...
# 3242  TIRA             21                      NaN                      NaN
# 3243  V510PI           10  2010-01-01 00:00:00.000  2010-01-01 00:00:00.000
# 3244  V536PI           10  2010-01-01 00:00:00.000  2010-01-01 00:00:00.000
# 3245  V552S1           10  2010-01-01 00:00:00.000  2010-01-01 00:00:00.000
# 3246  V552SI           10  2010-01-01 00:00:00.000  2010-01-01 00:00:00.000
#
#      DfLogIDExterna SvLinVal SvLinAVL
# ...

# %%
linhas2.merge(linhas, on='TpLinID', how='left')
# Out:
#       SvLinCodigo TpLinID         SvLinDataCriacao    SvLinDataInicOperacao  \
# 0     1002             10  2001-11-17 00:00:00.000  2003-05-17 00:00:00.000
# 1     1016             10  2002-05-17 00:00:00.000  2003-05-17 00:00:00.000
# 2     1016             51  2010-08-07 00:00:00.000  2010-08-07 00:00:00.000
# 3     1017             10  2012-11-24 00:00:00.000  2012-11-24 00:00:00.000
# 4     1018             10  2001-12-15 00:00:00.000  2003-05-17 00:00:00.000
# ...           ...     ...                      ...                      ...
# 3241  TIRA             21                      NaN                      NaN
# 3242  V510PI           10  2010-01-01 00:00:00.000  2010-01-01 00:00:00.000
# 3243  V536PI           10  2010-01-01 00:00:00.000  2010-01-01 00:00:00.000
# 3244  V552S1           10  2010-01-01 00:00:00.000  2010-01-01 00:00:00.000
# 3245  V552SI           10  2010-01-01 00:00:00.000  2010-01-01 00:00:00.000
#
# ...

# %%
p = 0.1
temp_de_viagem  = pd.read_csv(r'D:\Users\guilh\Documents\[[POLI] TCC 1\Dados\Dados Sptrans (CD Hackatona)\ABCadastro\ABSvTem.txt',
                encoding = 'ANSI',header = 0 ,  sep = '|', delimiter='|',skipinitialspace =True, na_values=lista_nula, skiprows=lambda i: i>0 and random.random() > p)
                
temp_de_viagem = temp_de_viagem.rename(columns=lambda x: x.strip())

temp_de_viagem.head()
# Out:
#    SvTemID  SvTemTempoIda  SvTemTempoVolta  SvTemFaixa  DfVgmCodigo
# 0        1            0.0              0.0           3  P
# 1        1           35.0             35.0           5  P
# 2        1           35.0             35.0           9  P
# 3        1           35.0             35.0          10  P
# 4        1           35.0             35.0          16  P

# %%
temp_de_viagem['SvTemTempoVolta'].mean()
# Out:
# 20.543837641449525

# %%
temp_de_viagem.loc[temp_de_viagem['SvTemTempoVolta']>0]['SvTemTempoVolta'].mean()
# Out:
# 60.37509943094903
